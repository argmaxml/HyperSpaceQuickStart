# %%
import json, re
import pandas as pd
from PIL import Image
import requests
import numpy as np
import pandas as pd
import clip
import math

# %%
def dotp(l):
    return np.array(l)@np.array(l)

def load_img_from_url(url):
    """
    Load image from url
    :param url: url of the image
    :return: PIL image object
    """
    return Image.open(requests.get(url, stream=True).raw)

def normalize_euclidean_norm(input_list):
    if abs(sum(input_list)) < 0.0000000000000001:
      return input_list
    euclidean_norm = math.sqrt(sum(x ** 2 for x in input_list))
    normalized_list = [x / euclidean_norm for x in input_list]
    return normalized_list
    
def display_doc(collection_name,id):
    input_document = hyperspace_client.get_document(collection_name, id)
    print(input_document['title'])
    im = load_img_from_url(input_document['img_link'])
    return im.resize((125,150))

# %% [markdown]
# # Load and create collection

# %%
config = {
    "configuration": {
        "id": {
            "type":"float"
        },
        "amznid":{
            "type":"keyword"
        },
        
        "title":{
        "type":"keyword"
        },
        "img_link": {
            "type":"keyword"
        },
        "img_clip": {
            "type": "dense_vector",
            "dim": 512,
            "index_type": "brute_force",
            "metric": "IP"
        },
        "txt_clip": {
            "type": "dense_vector",
            "dim": 512,
            "index_type": "brute_force",
            "metric": "IP"
        }
    }
}

with open('imagesearch_config.json', 'w') as f:
    f.write(json.dumps(config, indent=2))

# %%
import hyperspace

username = "----"
password = "----"

host = "https://beta.prod.hyper-space.xyz/"

hyperspace_client = hyperspace.HyperspaceClientApi(host=host,
                                                   username=username, password= password)

collection_name = 'amazon-images-norm'

# %%
hyperspace_client.collections_info()
# Out:
# {'collections': {'advec': {'creation_time': '2023-10-01T13:33:29Z',
#    'last_query_time': '2023-10-03T06:50:25Z',
#    'size': 89001},
#   'amazon-images-norm': {'creation_time': '2023-10-02T13:55:17Z',
#    'last_query_time': '2023-10-03T06:20:13Z',
#    'size': 100000}}}

# %% [markdown]
# # Create and load data

# %%
try:
    hyperspace_client.delete_collection(collection_name)
except:
    pass
hyperspace_client.create_collection('imagesearch_config.json', collection_name)
hyperspace_client.collections_info()
# Out:
# {'collections': {'advec': {'creation_time': '2023-10-01T13:33:29Z',
#    'last_query_time': '2023-10-02T08:45:41Z',
#    'size': 89001},
#   'amazon-images': {'creation_time': '2023-10-02T11:46:57Z',
#    'last_query_time': '2023-10-02T13:11:21Z',
#    'size': 99501},
#   'amazon-images-norm': {'creation_time': '2023-10-02T13:55:17Z', 'size': 0}}}

# %%
import numpy as np
import pandas as pd
img_vecs = np.load('data/img_clip_emb.npy')
text_vecs = np.load('data/text_clip_emb.npy')
metadata = pd.read_parquet("data/product_images.parquet")

# %%
metadata.iterrows()
# Out:
# <generator object DataFrame.iterrows at 0x0000027B30EBC890>

# %%
BATCH_SIZE = 500

batch = []
for i, ((_,metadata_row), img_vec,text_vec) in enumerate(zip(metadata.iterrows(), img_vecs, text_vecs)):
    row = {}
    row['amznid'] = metadata_row['asin']
    row['title'] = metadata_row['title']
    row['img_link'] = metadata_row['primary_image']
    row['img_clip'] = normalize_euclidean_norm(np.ndarray.tolist(img_vec))
    row['txt_clip'] = normalize_euclidean_norm(np.ndarray.tolist(text_vec))
    
    batch.append(hyperspace.Document(str(i), row))

    if i % BATCH_SIZE == 0:
        response = hyperspace_client.add_batch(batch, collection_name)
        batch.clear()
        print(i, response)
response = hyperspace_client.add_batch(batch, collection_name)
batch.clear()
print(i, response)       
hyperspace_client.commit(collection_name)
# Out:
# 0 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 1000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 1500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 2000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 2500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 3000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 3500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 4000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 4500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 5000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 5500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 6000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 6500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 7000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 7500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 8000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 8500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 9000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 9500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 10000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 10500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 11000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 11500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 12000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 12500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 13000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 13500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 14000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 14500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 15000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 15500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 16000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 16500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 17000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 17500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 18000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 18500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 19000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 19500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 20000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 20500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 21000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 21500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 22000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 22500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 23000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 23500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 24000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 24500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 25000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 25500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 26000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 26500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 27000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 27500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 28000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 28500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 29000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 29500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 30000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 30500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 31000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 31500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 32000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 32500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 33000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 33500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 34000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 34500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 35000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 35500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 36000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 36500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 37000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 37500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 38000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 38500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 39000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 39500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 40000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 40500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 41000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 41500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 42000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 42500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 43000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 43500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 44000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 44500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 45000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 45500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 46000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 46500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 47000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 47500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 48000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 48500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 49000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 49500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 50000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 50500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 51000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 51500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 52000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 52500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 53000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 53500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 54000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 54500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 55000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 55500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 56000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 56500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 57000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 57500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 58000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 58500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 59000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 59500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 60000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 60500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 61000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 61500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 62000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 62500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 63000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 63500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 64000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 64500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 65000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 65500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 66000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 66500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 67000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 67500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 68000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 68500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 69000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 69500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 70000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 70500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 71000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 71500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 72000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 72500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 73000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 73500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 74000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 74500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 75000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 75500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 76000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 76500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 77000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 77500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 78000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 78500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 79000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 79500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 80000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 80500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 81000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 81500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 82000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 82500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 83000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 83500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 84000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 84500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 85000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 85500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 86000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 86500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 87000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 87500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 88000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 88500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 89000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 89500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 90000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 90500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 91000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 91500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 92000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 92500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 93000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 93500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 94000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 94500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 95000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 95500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 96000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 96500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 97000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 97500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 98000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 98500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 99000 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 99500 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# 99999 {'code': 200,
#  'message': 'Batch successfully added',
#  'status': 'HTTP/1.1 200 OK'}
# {'code': 200, 'message': 'Dataset committed successfully', 'status': 'OK'}

# %%
hyperspace_client.collections_info()
# Out:
# {'collections': {'advec': {'creation_time': '2023-10-01T13:33:29Z',
#    'last_query_time': '2023-10-02T08:45:41Z',
#    'size': 89001},
#   'amazon-images': {'creation_time': '2023-10-02T11:46:57Z',
#    'last_query_time': '2023-10-02T13:11:21Z',
#    'size': 99501},
#   'amazon-images-norm': {'creation_time': '2023-10-02T13:55:17Z',
#    'size': 100000}}}

# %% [markdown]
# # Load clip model for generate embedings
# Note, should run
# `$ pip install git+https://github.com/openai/CLIP.git`
# to load model

# %%
import clip
device = "cpu"
# load model and image preprocessing
model, preprocess = clip.load("ViT-B/32", device=device, jit=False)
def load_and_emb(url):
    im = load_img_from_url(url)
    im_vec = preprocess(im).unsqueeze(0)
    im_emb = model.encode_image(im_vec)[0].tolist()
    return im,normalize_euclidean_norm(im_emb)
def _emb_txt(txts):
    tokens = clip.tokenize(txts)
    emb_txt = model.encode_text(tokens)[0].tolist()
    return normalize_euclidean_norm(emb_txt)

# %% [markdown]
# # Search

# %% [markdown]
# ## Db similar

# %%
test_id = 8520
input_document = hyperspace_client.get_document(collection_name, test_id)
display_doc(collection_name,test_id)
# Out:
# CamelBak Chute Mag BPA Free Water Bottle with Tritan Renew, 25oz, Cardinal
# <PIL.Image.Image image mode=RGB size=125x150>

# %%
query_with_knn = {
    'params': input_document,
    'knn' : {
        'img_clip' : {"boost":0},
        'txt_clip' : {"boost":1},
        'query' : {'boost':0}
    }
}

results = hyperspace_client.search(query_with_knn,
                                        size=10,
                                        collection_name=collection_name)
for res in results['similarity']:
    print(f"{res['document_id']} === {res['score']}")
    display(display_doc(collection_name,res['document_id']))
# Out:
# 8520 === 1.0000001192092896
# CamelBak Chute Mag BPA Free Water Bottle with Tritan Renew, 25oz, Cardinal
# <PIL.Image.Image image mode=RGB size=125x150>
# 8522 === 0.9846639633178711
# CamelBak Chute Mag BPA Free Water Bottle with Tritan Renew, 25oz, Coastal
# <PIL.Image.Image image mode=RGB size=125x150>
# 8512 === 0.983771800994873
# CamelBak Chute Mag BPA Free Water Bottle with Tritan Renew, 20oz, Lupine
# <PIL.Image.Image image mode=RGB size=125x150>
# 8510 === 0.9821794033050537
# CamelBak Chute Mag BPA Free Water Bottle with Tritan Renew, 50oz, Oxford
# <PIL.Image.Image image mode=RGB size=125x150>
# 8525 === 0.9796969294548035
# CamelBak Chute Mag BPA Free Water Bottle with Tritan Renew, 25oz, Lava
# <PIL.Image.Image image mode=RGB size=125x150>
# 8517 === 0.9794895648956299
# CamelBak Chute Mag BPA Free Water Bottle with Tritan Renew, 20oz, Lava
# <PIL.Image.Image image mode=RGB size=125x150>
# 8509 === 0.9772890210151672
# CamelBak Chute Mag BPA Free Water Bottle with Tritan Renew, 20oz, Clear
# <PIL.Image.Image image mode=RGB size=125x150>
# 8515 === 0.975383996963501
# CamelBak Chute Mag BPA Free Water Bottle with Tritan Renew, 50oz, Clear
# <PIL.Image.Image image mode=RGB size=125x150>
# 8511 === 0.9753615260124207
# CamelBak Chute Mag BPA Free Water Bottle with Tritan Renew, 32oz, Clear
# <PIL.Image.Image image mode=RGB size=125x150>
# 8523 === 0.9743634462356567
# CamelBak Chute Mag BPA Free Water Bottle with Tritan Renew, 32oz, Charcoal
# <PIL.Image.Image image mode=RGB size=125x150>

# %% [markdown]
# ## New input similarity

# %% [markdown]
# ### Text

# %%
input_text = ["pc for gamers"]
text_vec = _emb_txt(input_text)

query_with_knn = {
    'params': {
        "img_clip" : text_vec,
        "txt_clip": text_vec
    },
    'knn' : {
        'img_clip' : {"boost":0.8},
        'txt_clip' : {"boost":0.2},
        'query' : {'boost':0}
    }
}

results = hyperspace_client.search(query_with_knn,
                                        size=5,
                                        collection_name=collection_name)
for res in results['similarity']:
    print(f"{res['document_id']} === {res['score']}")
    display(display_doc(collection_name,res['document_id']))
# Out:
# 17034 === 0.24862849712371826
# iBUYPOWER Pro Gaming PC Computer Desktop TraceMR 234i (Intel i7-12700KF 3.6GHz,GeForce RTX 3080Ti 12GB, 16GB DDR4 RGB RAM, 1TB NVMe SSD, WiFi Ready, Windows 11 Home)
# <PIL.Image.Image image mode=RGB size=125x150>
# 44445 === 0.24552960693836212
# MSI Aegis RS Gaming Desktop PC, Intel Core i7-12700KF, GeForce RTX 3060 Ti, 16GB Memory (Dual-CHL), 1TB NVMe SSD, WiFi 6E, Liquid Cooling, USB Type-C, Win11 Home, Keyboard and Mouse (12TG-285US)
# <PIL.Image.Image image mode=RGB size=125x150>
# 13884 === 0.23975899815559387
# Thermaltake H570 TG Black ATX Mid Tower ARGB Tempered Glass Computer Case Chassis with Mesh Front Panel CA-1T9-00M1WN-00
# <PIL.Image.Image image mode=RGB size=125x150>
# 19857 === 0.2365604192018509
# MSI MPG Velox 100R - Mid-Tower Gaming PC Case - Tempered Glass Side Panel - 4 x 120mm ARGB Fans - Liquid Cooling Support up to 360mm Radiator - Mesh Panel for Optimized Airflow
# <PIL.Image.Image image mode=RGB size=125x150>
# 17274 === 0.23064319789409637
# Corsair iCUE LS100 LED Smart Lighting Strip Starter Kit
# <PIL.Image.Image image mode=RGB size=125x150>

# %% [markdown]
# ### image

# %%
url = "https://m.media-amazon.com/images/I/71N80IX6mxL.__AC_SX300_SY300_QL70_FMwebp_.jpg"
im,im_emb = load_and_emb(url)
im
# Out:
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=300x278>

# %%
query_with_knn = {
    'params': {
        "img_clip" : im_emb,
        "txt_clip": im_emb
    },
    'knn' : {
        'img_clip' : {"boost":1},
        'txt_clip' : {"boost":0},
        'query' : {'boost':0}
    }
}

results = hyperspace_client.search(query_with_knn,
                                        size=5,
                                        collection_name=collection_name)
for res in results['similarity']:
    print(f"{res['document_id']} === {res['score']}")
    display(display_doc(collection_name,res['document_id']))
# Out:
# 35836 === 0.780569851398468
# GUND LINE Friends Sally Round Body Pillow Soft Plush Stuffed, Yellow, 12”
# <PIL.Image.Image image mode=RGB size=125x150>
# 38147 === 0.7750683426856995
# Intex Mega Swan Ride-On Inflatable Pool Float
# <PIL.Image.Image image mode=RGB size=125x150>
# 40993 === 0.768219530582428
# GUND LINE Friends Squid Sally Chick Plush Stuffed Animal, 7"
# <PIL.Image.Image image mode=RGB size=125x150>
# 44056 === 0.7675026059150696
# FINIS Manta Swim Training Hand Paddle for Competitive Swimming Exercise , Small
# <PIL.Image.Image image mode=RGB size=125x150>
# 21022 === 0.7408950924873352
# GUND Baby Baby Toothpick Aubrey Flamingo Plush Stuffed Animal, Pink, 16"
# <PIL.Image.Image image mode=RGB size=125x150>
